# %%
import os
import pandas as pd
import joblib

# %%
df = pd.read_csv("../data/Processed/test_winequality.csv")

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.6             0.350         0.60             2.6      0.073
# 1            8.9             0.590         0.50             2.0      0.337
# 2            8.8             0.610         0.14             2.4      0.067
# 3            8.5             0.370         0.32             1.8      0.066
# 4            6.8             0.785         0.00             2.4      0.104
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 23.0                  44.0  0.99656  3.38       0.79
# 1                 27.0                  81.0  0.99640  3.04       1.61
# 2                 10.0                  42.0  0.99690  3.19       0.59
# 3                 26.0                  51.0  0.99456  3.38       0.72
# 4                 14.0                  30.0  0.99660  3.52       0.55
#
#    alcohol  TARGET
# 0     11.1       6
# 1      9.5       6
# 2      9.5       5
# 3     11.8       6
# 4     10.7       6

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'TARGET'],
#       dtype='object')

# %%
model = joblib.load("../prediction_service/model/model.joblib")

# %%
df.describe().T
# Out:
#                       count       mean        std      min        25%  \
# fixed_acidity         320.0   8.276563   1.792106  5.00000   7.000000
# volatile_acidity      320.0   0.530625   0.174592  0.18000   0.398750
# citric_acid           320.0   0.271375   0.197492  0.00000   0.080000
# residual_sugar        320.0   2.508750   1.251345  0.90000   1.900000
# chlorides             320.0   0.091256   0.060100  0.03400   0.070750
# free_sulfur_dioxide   320.0  15.346875  10.210327  1.00000   7.000000
# total_sulfur_dioxide  320.0  45.687500  34.099833  6.00000  21.000000
# density               320.0   0.996738   0.001929  0.99007   0.995657
# pH                    320.0   3.314469   0.152822  2.89000   3.210000
# sulphates             320.0   0.653687   0.170090  0.37000   0.540000
# alcohol               320.0  10.381146   1.040919  8.40000   9.500000
# TARGET                320.0   5.606250   0.768477  3.00000   5.000000
#
#                             50%      75%       max
# fixed_acidity          7.800000   9.2000   15.6000
# volatile_acidity       0.530000   0.6450    1.2400
# citric_acid            0.250000   0.4225    0.7600
# residual_sugar         2.200000   2.6000   13.4000
# chlorides              0.079000   0.0900    0.6110
# free_sulfur_dioxide   13.000000  20.2500   72.0000
# total_sulfur_dioxide  37.500000  61.0000  289.0000
# density                0.996875   0.9978    1.0032
# pH                     3.310000   3.4025    3.9000
# sulphates              0.610000   0.7200    1.6100
# alcohol               10.200000  11.0000   14.0000
# TARGET                 6.000000   6.0000    8.0000

# %%
overview = df.describe()

# %%
overview.loc[["min", "max"]].to_json("schema_in.json")

# %%
model.get_params()
# Out:
# {'alpha': 0.75,
#  'copy_X': True,
#  'fit_intercept': True,
#  'l1_ratio': 0.3,
#  'max_iter': 1000,
#  'normalize': False,
#  'positive': False,
#  'precompute': False,
#  'random_state': 9,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'warm_start': False}

# %%
model(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-c65e5ea6c0f9> in <module>
# ----> 1 model(df)
#
# TypeError: 'ElasticNet' object is not callable

# %%
model.predict(df)
# Out:
# array([[ 7.74571867,  0.52664402,  0.27028343, ...,  3.31054526,
#          0.65912203, 10.81936673],
#        [ 8.73621803,  0.5332412 ,  0.2731117 , ...,  3.30677153,
#          0.66110911,  9.83772558],
#        [ 8.71285076,  0.52628742,  0.27090585, ...,  3.31074925,
#          0.65901463,  9.93339086],
#        ...,
#        [ 7.08363921,  0.52272137,  0.26852423, ...,  3.3127891 ,
#          0.65794053, 10.37330619],
#        [ 7.80559609,  0.53555913,  0.27309423, ...,  3.30544562,
#          0.66180727,  9.76682796],
#        [ 8.72971948,  0.52218647,  0.26964095, ...,  3.31309508,
#          0.65777942, 10.27947485]])

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count     320.000000        320.000000   320.000000      320.000000
# mean        8.276563          0.530625     0.271375        2.508750
# std         1.792106          0.174592     0.197492        1.251345
# min         5.000000          0.180000     0.000000        0.900000
# 25%         7.000000          0.398750     0.080000        1.900000
# 50%         7.800000          0.530000     0.250000        2.200000
# 75%         9.200000          0.645000     0.422500        2.600000
# max        15.600000          1.240000     0.760000       13.400000
#
#         chlorides  free_sulfur_dioxide  total_sulfur_dioxide     density  \
# count  320.000000           320.000000            320.000000  320.000000
# mean     0.091256            15.346875             45.687500    0.996738
# std      0.060100            10.210327             34.099833    0.001929
# min      0.034000             1.000000              6.000000    0.990070
# 25%      0.070750             7.000000             21.000000    0.995657
# 50%      0.079000            13.000000             37.500000    0.996875
# 75%      0.090000            20.250000             61.000000    0.997800
# max      0.611000            72.000000            289.000000    1.003200
#
#                pH   sulphates     alcohol      TARGET
# count  320.000000  320.000000  320.000000  320.000000
# mean     3.314469    0.653687   10.381146    5.606250
# std      0.152822    0.170090    1.040919    0.768477
# min      2.890000    0.370000    8.400000    3.000000
# 25%      3.210000    0.540000    9.500000    5.000000
# 50%      3.310000    0.610000   10.200000    6.000000
# 75%      3.402500    0.720000   11.000000    6.000000
# max      3.900000    1.610000   14.000000    8.000000
